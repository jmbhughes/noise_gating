# %%
# %cd ../src
import glob
from astropy.io import fits
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# [Errno 2] No such file or directory: '../src'
# /Users/mhughes/google_drive/codedungeon/noise_gating

# %%
with open("/Users/mhughes/Desktop/data.pickle", "rb") as f:
    [themes, weights, thematic_map] = pickle.load(f)

# %%
weights[1][:,:] = -10**10
weights[6][:,:] = -10**10

# %%
plt.figure()
plt.imshow(np.argmax(np.stack(weights), axis=0))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
themes
# Out:
# ['coronal_hole',
#  'flare',
#  'bright_region',
#  'limb',
#  'outer_space',
#  'quiet_corona',
#  'filament',
#  'prominence']

# %%
# Out:
# array([[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        ...,
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan]], dtype=float32)

# %%
plt.figure()
plt.imshow(weights[0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
glob.glob("/Users/mhughes/Desktop/bayesian_june/*")
# Out:
# ['/Users/mhughes/Desktop/bayesian_june/june_fits_0',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_1',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_10',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_11',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_12',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_13',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_14',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_15',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_16',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_17',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_18',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_19',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_2',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_20',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_21',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_22',
#  '/Users/mhughes/Desktop/bayesian_june/june_fits_23',
# ...

# %%
date = 20170604

# %%
str(date)[:4]
# Out:
# '2017'

# %%
str(date)[4:6]
# Out:
# '06'

# %%
str(date)[6:]
# Out:
# '04'

# %%
time = 603

# %%
if len(str(time)) == 4:
    hour = str(time)[:2]
    minute = str(time)[2:]
elif len(str(time)) == 3:
    hour = "0" + str(time)[0]
    minute = str(time)[1:]
else: 
    hour = "00"
    minute = "00"

# %%
hour, minute
# Out:
# ('06', '03')

# %%
fns = glob.glob("/Users/mhughes/Desktop/june_fits_neural_dir2/*.pickle")

# %%
for i, f in enumerate(fns):
    print(i, f)
# Out:
# 0 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_0_data.pickle
# 1 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_10_data.pickle
# 2 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_11_data.pickle
# 3 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_12_data.pickle
# 4 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_13_data.pickle
# 5 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_14_data.pickle
# 6 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_15_data.pickle
# 7 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_16_data.pickle
# 8 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_17_data.pickle
# 9 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_18_data.pickle
# 10 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_19_data.pickle
# 11 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_1_data.pickle
# 12 /Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_20_data.pickle
# ...

# %%
import os

# %%
for fn in fns:
    dirname = fn.split("/")[-1].split("_data.pickle")[0]
    os.system("mkdir /Users/mhughes/Desktop/june_fits_neural_dir2/" + dirname)
    movers = glob.glob("/Users/mhughes/Desktop/june_fits_neural_dir2/*" + dirname + "_*")
    for mover in movers:
        os.system("mv {}  /Users/mhughes/Desktop/june_fits_neural_dir2/{}".format(mover, dirname))

# %%
dirname = fns[0].split("/")[-1].split("_data.pickle")[0]

# %%
glob.glob("/Users/mhughes/Desktop/june_fits_neural_dir2/*" + dirname + "_*")
# Out:
# ['/Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_0_3color.png',
#  '/Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_0_data.pickle',
#  '/Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_0_map.png']

# %%
fns = glob.glob("/Users/mhughes/Desktop/june_fits_neural_dir2/*")

# %%
fns[0]
# Out:
# '/Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_0'

# %%
glob.glob(fns[0] + "/*.pickle")
# Out:
# ['/Users/mhughes/Desktop/june_fits_neural_dir2/june_fits_0/june_fits_0_data.pickle']

# %%
for fn in fns:
    movers = glob.glob(fn + "/*.pickle")
    os.system("mv {} {}/data.pickle".format(movers[0], fn))
