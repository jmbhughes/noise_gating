# %%
import glob
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
channels = ["94", "131", "171", "195", "284", "304"]

# %%
proc_fits_path = "/Volumes/Herschel/data/proc_fits/"
june_fits_path = "/Volumes/Herschel/data/june_fits/"

# %%
proc_fits_vals, june_fits_vals = dict(), dict()
for channel in channels:
    proc_fits_vals[channel] = []
    for fn in glob.glob(proc_fits_path + channel + "/*.fits"):
        if "normed" not in fn:
            with fits.open(fn) as img:
                proc_fits_vals[channel].append(np.mean(img[0].data))
    june_fits_vals[channel] = []
    for fn in glob.glob(june_fits_path + channel + "/*.fits"):
        if "normed" not in fn:
            with fits.open(fn) as img:
                june_fits_vals[channel].append(np.mean(img[0].data))

# %%
list(proc_fits_vals.keys()), list(june_fits_vals.keys())
# Out:
# (['171', '284', '304', '94', '131', '195'],
#  ['171', '284', '304', '94', '131', '195'])

# %%
proc_fits_vals['195']

# %%
[val for val in proc_fits_vals['195'] if not np.isinf(val)]
# Out:
# [0.40273163,
#  0.40272799,
#  0.40275571,
#  0.40277779,
#  0.40276361,
#  0.40284234,
#  0.40293956,
#  0.40285146,
#  0.40302199,
#  0.40315196,
#  0.40335232,
#  0.40337169,
#  0.40336859,
#  0.40333807,
#  0.40341052,
#  0.4033176,
#  0.4034006,
#  0.40341723,
#  0.40343213,
#  0.40345857,
#  0.40361577,
#  0.40351391,
#  0.4036639,
#  0.40367368,
#  0.40377918,
#  0.40382594,
#  0.4038718,
#  0.40379629,
#  0.4038108,
#  0.40382534,
#  0.40386701,
#  0.40399808,
#  0.4041051,
#  0.40398371,
#  0.40398923,
#  0.40390557,
#  0.40385142,
#  0.40378097,
#  0.40383589,
#  0.40380788,
#  0.4038223,
#  0.4038066,
#  0.40397862,
#  0.40401402,
#  0.40406516,
#  0.40403023,
#  0.40416864,
#  0.40419137,
#  0.40430501,
#  0.40418538,
#  0.40420306,
#  0.40423915,
#  0.40435216,
#  0.40451226,
#  0.40466645,
#  0.40465087,
#  0.40468526,
#  0.40466475,
#  0.40478075,
#  0.40481529,
#  0.40485251,
#  0.40493548,
#  0.40494442,
#  0.40496075,
#  0.4049685,
#  0.40501153,
#  0.40517193,
# ...

# %%
channel = "171"

# %%
fig, axes = plt.subplots(2, sharey=True)
axes[0].set_title("April 18th")
axes[0].plot([val for val in proc_fits_vals[channel] if not np.isinf(val)])
axes[1].set_title("June")
axes[1].plot([val for val in june_fits_vals[channel] if not np.isinf(val)])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
channel = "131"

# %%
fig, axes = plt.subplots(2, sharey=True)
axes[0].set_title("April 18th")
axes[0].plot([val for val in proc_fits_vals[channel] if not np.isinf(val)])
axes[1].set_title("June")
axes[1].plot([val for val in june_fits_vals[channel] if not np.isinf(val)])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots(2, sharex=True, sharey=True)
axes[0].hist([val for val in proc_fits_vals[channel] if not np.isinf(val)])
axes[0].set_title("April 18th")
axes[1].hist([val for val in june_fits_vals[channel] if not np.isinf(val)])
axes[1].set_title("June")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for fn in proc_fits_94:
    with fits.open(fn) as img:
        print(np.mean(img[0].data))
# Out:
# 0.0204809
# 0.0204119
# 0.0204508
# 0.0205257
# 0.0204702
# 0.0204996
# 0.0206951
# 0.0204989
# 0.0205669
# 0.0207139
# 0.0205071
# 0.0206973
# 0.0206664
# 0.0204745
# 0.0206495
# 0.0206079
# 0.0208709
# 0.0205013
# 0.0206293
# 0.0206805
# 0.0208409
# 0.0208196
# 0.0208314
# 0.0208583
# 0.0208471
# 0.0205523
# 0.0206609
# 0.020772
# 0.0209032
# 0.0206277
# 0.0206568
# 0.0208186
# 0.0207089
# 0.0208347
# 0.0207596
# 0.0208204
# 0.0208294
# 0.0209565
# 0.0210224
# 0.020909
# 0.0209659
# 0.0210276
# 0.0212481
# 0.021345
# 0.0214019
# 0.0215429
# 0.0215311
# 0.0217272
# 0.021789
# 0.0222255
# 0.0224412
# 0.0223769
# 0.0228559
# 0.0232867
# 0.0235714
# 0.0241124
# 0.024557
# 0.0249954
# 0.0257825
# 0.0264856
# 0.0271114
# 0.0276367
# 0.0283994
# 0.0291274
# 0.0298918
# 0.0306032
# 0.031183
# 0.03166
# 0.0319475
# 0.0323114
# 0.0323983
# 0.0323967
# 0.0324519
# 0.0319678
# 0.0315089
# 0.0313751
# 0.0307782
# 0.0303987
# 0.0302431
# 0.0299489
# 0.0292444
# 0.0292108
# 0.0288548
# 0.0282854
# ...
