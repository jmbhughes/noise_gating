# %%
import glob
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
channels = ["94", "131", "171", "195", "284", "304"]

# %%
proc_fits_path = "/Volumes/Herschel/data/proc_fits/"
june_fits_path = "/Volumes/Herschel/data/june_fits/"

# %%
proc_fits_vals, june_fits_vals = dict(), dict()
for channel in channels:
    proc_fits_vals[channel] = []
    for fn in glob.glob(proc_fits_path + channel + "/*.fits"):
        if "normed" not in fn:
            with fits.open(fn) as img:
                proc_fits_vals[channel].append(np.mean(img[0].data))
    june_fits_vals[channel] = []
    for fn in glob.glob(june_fits_path + channel + "/*.fits"):
        if "normed" not in fn:
            with fits.open(fn) as img:
                june_fits_vals[channel].append(np.mean(img[0].data))

# %%
channel = "304"
fig, axes = plt.subplots(2, sharex=True, sharey=True)
axes[0].hist(proc_fits_vals[channel])
axes[1].hist(june_fits_vals[channel])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(june_fits_vals['304'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
june_fits_94 = glob.glob("/Volumes/Herschel/data/june_fits/94/*.fits")

# %%
for fn in proc_fits_94:
    with fits.open(fn) as img:
        print(np.mean(img[0].data))
# Out:
# 0.0204809
# 0.0204119
# 0.0204508
# 0.0205257
# 0.0204702
# 0.0204996
# 0.0206951
# 0.0204989
# 0.0205669
# 0.0207139
# 0.0205071
# 0.0206973
# 0.0206664
# 0.0204745
# 0.0206495
# 0.0206079
# 0.0208709
# 0.0205013
# 0.0206293
# 0.0206805
# 0.0208409
# 0.0208196
# 0.0208314
# 0.0208583
# 0.0208471
# 0.0205523
# 0.0206609
# 0.020772
# 0.0209032
# 0.0206277
# 0.0206568
# 0.0208186
# 0.0207089
# 0.0208347
# 0.0207596
# 0.0208204
# 0.0208294
# 0.0209565
# 0.0210224
# 0.020909
# 0.0209659
# 0.0210276
# 0.0212481
# 0.021345
# 0.0214019
# 0.0215429
# 0.0215311
# 0.0217272
# 0.021789
# 0.0222255
# 0.0224412
# 0.0223769
# 0.0228559
# 0.0232867
# 0.0235714
# 0.0241124
# 0.024557
# 0.0249954
# 0.0257825
# 0.0264856
# 0.0271114
# 0.0276367
# 0.0283994
# 0.0291274
# 0.0298918
# 0.0306032
# 0.031183
# 0.03166
# 0.0319475
# 0.0323114
# 0.0323983
# 0.0323967
# 0.0324519
# 0.0319678
# 0.0315089
# 0.0313751
# 0.0307782
# 0.0303987
# 0.0302431
# 0.0299489
# 0.0292444
# 0.0292108
# 0.0288548
# 0.0282854
# 0.0285142
# 0.027934
# 0.0277291
# 0.0274246
# 0.0274511
# 0.0272388
# 0.0272323
# 0.0270766
# 0.0269102
# 0.0265878
# 0.0265052
# 0.0264845
# 0.026362
# 0.0262076
# 0.0262757
# 0.0260237
# 0.026254
# 0.0260684
# 0.0258365
# 0.0257462
# 0.025834
# 0.025776
# 0.0257259
# 0.0257863
# 0.0256885
# 0.0258679
# 0.0257336
# 0.0256764
# 0.025602
# 0.0256083
# 0.0258959
# 0.0257409
# 0.0256288
# 0.0256782
# 0.0257876
# 0.0256811
# 0.0255465
# 0.0256948
# 0.0257973
# 0.0257458
# 0.0258735
# 0.0259809
# 0.0256798
# 0.0256268
# 0.0257749
# 0.0256803
# 0.0257107
# 0.0255211
# 0.025749
# 0.0254819
# 0.0258535
# 0.0256142
# 0.026126
# 0.0255152
# 0.0255918
# 0.0256403
# 0.0257709
# 0.0256287
# 0.0256046
# 0.0255372
# 0.0257167
# 0.0255485
# 0.0258889
# 0.0256378
# 0.0259727
# 0.0254746
# 0.0255524
# 0.0261482
# 0.0259847
# 0.0258797
# 0.0253179
# 0.0258364
# 0.025214
# 0.0257438
# 0.02588
# 0.0259051
# 0.0256627
# 0.025097
# 0.0255745
# 0.0255546
# 0.0254155
# 0.0253477
# 0.0253694
# 0.0254255
# 0.0253591
# 0.0252456
# 0.0251714
# 0.0251527
# 0.0248963
# 0.0251339
# 0.0250016
# 0.0248965
# 0.0248626
# 0.0247828
# 0.024784
# 0.00929368

# %%
glob
